# %%
# auto_fix_issues.py
"""
Auto-fixer for the project:
- Ensures publish_ready_cleaned/*.html exist (runs user's generator or fallback)
- Deduplicates identical article files (keeps first, removes duplicates)
- Ensures pin_images/*.png exist and are valid (generates missing/corrupt images)
- Inserts <img> tag (raw URL template) before first <h1> in each HTML if missing
- Stops BEFORE publishing to Blogger
Prints 'ALL FIXED ✅' when all checks pass.
"""
from pathlib import Path
from hashlib import md5
import sys, subprocess, time

# try imports
try:
    from PIL import Image, ImageDraw, ImageFont
except Exception:
    raise SystemExit("Pillow is required. Run: pip install pillow")

try:
    import requests
except Exception:
    requests = None

# ---------- helpers ----------
ROOT = Path.cwd()
TRENDS = ROOT / "trends_list.txt"
PUB_DIR = ROOT / "publish_ready_cleaned"
PIN_DIR = ROOT / "pin_images"

IMG_W, IMG_H = 1000, 1500
MARGIN = 40
FONT_CANDIDATES = [
    "DejaVuSans-Bold.ttf",
    "/usr/share/fonts/truetype/dejavu/DejaVuSans-Bold.ttf",
    "/usr/share/fonts/truetype/liberation/LiberationSans-Bold.ttf"
]
DEFAULT_FONT_SIZE = 56

def run_if_exists(pyfile: Path):
    if pyfile.exists():
        print(f"> Running: {pyfile.name}")
        try:
            p = subprocess.run([sys.executable, str(pyfile)], check=True, capture_output=True, text=True, timeout=300)
            if p.stdout:
                print(p.stdout)
            if p.stderr:
                print("STDERR:", p.stderr)
            return True
        except Exception as e:
            print(f"Warning: running {pyfile.name} failed: {e}")
            return False
    return False

def safe_filename(s: str) -> str:
    name = "".join(c if c.isalnum() or c in "-_" else "_" for c in s.strip())[:80]
    if not name or name[0] == "-":
        name = "pin_" + name.lstrip("-")
    return name or "pin_image"

def load_font(size=DEFAULT_FONT_SIZE):
    for p in FONT_CANDIDATES:
        try:
            return ImageFont.truetype(p, size)
        except Exception:
            continue
    return ImageFont.load_default()

def text_size(draw, text, font):
    try:
        bbox = draw.textbbox((0,0), text, font=font)
        return bbox[2]-bbox[0], bbox[3]-bbox[1]
    except Exception:
        pass
    try:
        return draw.textsize(text, font=font)
    except Exception:
        pass
    try:
        mask = font.getmask(text)
        return mask.size
    except Exception:
        pass
    return (8*len(text), getattr(font, "size", DEFAULT_FONT_SIZE))

def make_pin(title: str, out_dir: Path):
    out_dir.mkdir(parents=True, exist_ok=True)
    img = Image.new("RGB", (IMG_W, IMG_H), color=(255,255,255))
    draw = ImageDraw.Draw(img)
    font = load_font(DEFAULT_FONT_SIZE)
    words = title.split() or ["Sample","Title"]
    lines, cur = [], ""
    for w in words:
        cand = (cur + " " + w).strip() if cur else w
        tw,_ = text_size(draw, cand, font)
        if tw <= IMG_W - 2*MARGIN:
            cur = cand
        else:
            if cur:
                lines.append(cur)
            cur = w
    if cur:
        lines.append(cur)
    # shrink font if needed
    for _ in range(6):
        widths = [text_size(draw, ln, font)[0] for ln in lines] if lines else [0]
        if widths and max(widths) <= IMG_W - 2*MARGIN:
            break
        new_size = max(10, int(getattr(font, "size", DEFAULT_FONT_SIZE) * 0.85))
        font = load_font(new_size)
    heights = [text_size(draw, ln, font)[1] for ln in lines]
    total_h = sum(heights) + (len(lines)-1)*12
    current_y = (IMG_H - total_h)//2
    for ln, h in zip(lines, heights):
        w,_ = text_size(draw, ln, font)
        x = (IMG_W - w)//2
        draw.text((x, current_y), ln, fill=(20,20,20), font=font)
        current_y += h + 12
    name = safe_filename(title)
    out = out_dir / f"{name}.png"
    img.save(out, format="PNG", optimize=True)
    return out

# ---------- core fixes ----------
def ensure_trends_and_articles():
    # run user's fetch_trends_alternative.py if exists else minimal fallback
    if not run_if_exists(ROOT / "fetch_trends_alternative.py"):
        print("> No fetch_trends_alternative.py ran — ensure trends_list.txt exists or create fallback.")
        if not TRENDS.exists():
            fallback = ["Artificial Intelligence","Healthy Eating","Remote Work Trends","Sustainable Energy"]
            TRENDS.write_text("\n".join(fallback), encoding="utf-8")
            print("> Wrote fallback trends_list.txt")
    # run user's generator if exists
    ran_gen = run_if_exists(ROOT / "generate_articles.py") or run_if_exists(ROOT / "generate_content.py")
    if not ran_gen:
        # generate simple HTML files from trends_list
        print("> Generating fallback HTML articles from trends_list.txt")
        PUB_DIR.mkdir(parents=True, exist_ok=True)
        lines = [l.strip() for l in TRENDS.read_text(encoding="utf-8").splitlines() if l.strip()] if TRENDS.exists() else ["Sample Topic"]
        for t in lines:
            title = " ".join(w.capitalize() for w in t.replace("_"," ").replace("-"," ").split())
            safe = safe_filename(title)
            html = f"<h1>{title}</h1>\n<p>This is an auto-generated fallback article about {title}.</p>\n"
            (PUB_DIR / f"{safe}.html").write_text(html, encoding="utf-8")
        print(f"> Generated {len(lines)} fallback HTML articles.")

def deduplicate_articles():
    if not PUB_DIR.exists():
        return
    seen = {}
    removed = []
    for f in sorted(PUB_DIR.glob("*.html")):
        txt = f.read_text(encoding="utf-8")
        h = md5(txt.encode("utf-8")).hexdigest()
        if h in seen:
            # remove duplicate file
            f.unlink()
            removed.append(f.name)
        else:
            seen[h] = f
    if removed:
        print("> Removed duplicate articles:", removed)

def ensure_images_and_html():
    PUB_DIR.mkdir(parents=True, exist_ok=True)
    PIN_DIR.mkdir(parents=True, exist_ok=True)
    htmls = sorted(PUB_DIR.glob("*.html"))
    if not htmls:
        raise SystemExit("No HTML articles found after generation — aborting.")
    fixed_images = []
    for h in htmls:
        title = h.stem.replace("_"," ").strip()
        if not title:
            title = "Article"
        # compute safe image name
        img_name = safe_filename(title) + ".png"
        img_path = PIN_DIR / img_name
        need_generate = False
        if not img_path.exists() or img_path.stat().st_size == 0:
            need_generate = True
        else:
            # verify image can be opened
            try:
                im = Image.open(img_path)
                im.verify()
            except Exception:
                need_generate = True
        if need_generate:
            print(f"> Generating image for: {title}")
            out = make_pin(title, PIN_DIR)
            fixed_images.append(out.name)
        # ensure HTML has <img> tag pointing to raw template
        text = h.read_text(encoding="utf-8")
        if "<img" not in text.lower():
            raw_tpl = f"https://raw.githubusercontent.com/<username>/<repo>/main/pin_images/{img_name}"
            img_tag = f'<p><img src="{raw_tpl}" alt="{title}" /></p>\n'
            # insert before first <h1> if present
            lowered = text.lower()
            idx = lowered.find("<h1")
            if idx != -1:
                new_text = text[:idx] + img_tag + text[idx:]
            else:
                new_text = img_tag + text
            h.write_text(new_text, encoding="utf-8")
    if fixed_images:
        print("> Generated images:", fixed_images)

def final_check():
    # reuse checks: images exist and nonzero; HTMLs have <h1> and <img>
    imgs = list(PIN_DIR.glob("*.png"))
    bad_imgs = [p.name for p in imgs if p.stat().st_size == 0]
    if bad_imgs:
        print("ERROR: zero-byte images:", bad_imgs); return False
    htmls = list(PUB_DIR.glob("*.html"))
    missing = []
    for h in htmls:
        t = h.read_text(encoding="utf-8").lower()
        if "<h1" not in t or "<img" not in t:
            missing.append(h.name)
    if missing:
        print("ERROR: some HTML missing <h1> or <img>:", missing); return False
    return True

# ---------- run ----------
def main():
    print("Project root:", ROOT)
    ensure_trends_and_articles()
    deduplicate_articles()
    ensure_images_and_html()
    ok = final_check()
    if ok:
        print("\nALL FIXED ✅ — Articles and images are present and valid.")
        print("Next: git add/commit/push the changes to your GitHub repo.")
        sys.exit(0)
    else:
        print("\nSOME ISSUES REMAIN ❗ — see messages above and fix manually.")
        sys.exit(2)

if __name__ == "__main__":
    main()
# Out:
# Project root: C:\Users\bc\ملف نشر المحتوى
# > No fetch_trends_alternative.py ran — ensure trends_list.txt exists or create fallback.
# > Generating fallback HTML articles from trends_list.txt
# > Generated 40 fallback HTML articles.
# > Generating image for: 10 Years Of Writing A Blog Nobody Reads
# > Generating image for: 1964 recompiling engine documentation 2001 pdf
# > Generating image for: A New Ai Winter Is Coming
# > Generating image for: a new little prince museum has opened its doors in switzerland
# > Generating image for: a new myth appeared during the presidential campaign of andrew jackson
# > Generating image for: A Vector Graphics Workstation From The 70s
# > Generating image for: accessowl yc s22 is hiring a technical account manager iam
# > Generating image for: After Windows Update  Password Icon Invisible  Click Where It Used To Be
# > Generating image for: Ai Agents Find  4 6m In Blockchain Smart Contract Exploits
# > Generating image for: all it takes is for one to work out
# > Generating image for: Amazon Faces Faa Probe After Delivery Drone Snaps Internet Cable In Texas
# > Generating image for: americans no longer see four year college degrees as worth the cost
# > Generating image for: an update on the farphone s battery
# > Generating image for: anthony bourdain s lost li st s
# > Generating image for: Arcee Trinity Mini  Us Trained Moe Model
# > Generating image for: Around The World  Part 27  Planting Trees
# > Generating image for: Ask Hn  Quality Of Recent Gens Of Dell lenovo Laptops Worse Than 10 Years Ago
# > Generating image for: Ask Hn  Who Is Hiring   december 2025
# > Generating image for: Ask Hn  Who Wants To Be Hired   december 2025
# > Generating image for: be like clippy
# > Generating image for: Beej s Guide To Learning Computer Science
# > Generating image for: Better Auth  yc X25  Is Hiring
# > Generating image for: blender facial animation tool what else should it do
# > Generating image for: bronze age mega settlement in kazakhstan has advanced urban planning, metallurgy
# > Generating image for: Cartographers Have Been Hiding Illustrations Inside Switzerland s Maps  2020
# > Generating image for: Cloud Init On Raspberry Pi Os
# > Generating image for: Codex  Opus  Gemini Try To Build Counter Strike
# > Generating image for: datacenters in space aren t going to work
# > Generating image for: Deepseek V3 2  Pushing The Frontier Of Open Large Language Models  pdf
# > Generating image for: dns loc record 2014
# > Generating image for: Durin Is A Library For Reading And Writing The Dwarf Debugging Format
# > Generating image for: Games Using Anti Cheats And Their Compatibility With Gnu linux Or Wine proton
# > Generating image for: generating cats with learned lookup tables
# > Generating image for: Ghostty Compiled To Wasm With Xterm js Api Compatibility
# > Generating image for: Google  Nvidia  And Openai
# > Generating image for: Google Unkills Jpeg Xl
# > Generating image for: hardening the c standard library at scale
# > Generating image for: High Income Job Losses Are Cooling Housing Demand
# > Generating image for: Imanim  Modern Animation Capabilities To Imgui Applications
# > Generating image for: India Orders Smartphone Makers To Preload State Owned Cyber Safety App
# > Generating image for: Instagram Chief Orders Staff Back To The Office Five Days A Week In 2026
# > Generating image for: It s Been A Very Hard Year
# > Generating image for: John Giannandrea To Retire From Apple
# > Generating image for: landlock ing linux
# > Generating image for: Last Week On My Mac  Losing Confidence
# > Generating image for: leak confirms openai is preparing ads on chatgpt for public roll out
# > Generating image for: learning feynman s trick for integrals
# > Generating image for: let go of stackoverflow communities must take ownership
# > Generating image for: matrix core programming on amd cdna architecture
# > Generating image for: meshtastic
# > Generating image for: mint is not tex
# > Generating image for: Mozilla s Latest Quagmire
# > Generating image for: post mortem of shai hulud attack on november 24th, 2025
# > Generating image for: rare x ray images of a 4 5 ton satellite that returned intact from space
# > Generating image for: Response To  ruby Is Not A Serious Programming Language
# > Generating image for: Reverse Math Shows Why Hard Problems Are Hard
# > Generating image for: scala
# > Generating image for: Self Hosting A Matrix Server For 5 Years
# > Generating image for: stopping bad guys from using my open source project feedback wanted
# > Generating image for: student perceptions of ai coding assistants in learning
# > Generating image for: Sycophancy Is The First Llm  dark Pattern
# > Generating image for: Tested  1981 Datsun 280zx Turbo  1981
# > Generating image for: testing shows automotive glassbreakers can t break modern automotive glass
# > Generating image for: the http query method
# > Generating image for: the origins of scala 2009
# > Generating image for: The Penicillin Myth
# > Generating image for: Tom Stoppard Has Died
# > Generating image for: we re learning more about what vitamin d does
# > Generating image for: What Will Enter The Public Domain In 2026
# > Generating image for: Why I Stopped Using Json For My Apis
# > Generating image for: Why Xor Eax  Eax
# > Generating image for: zero knowlege proof of compositeness
# > Generating image for: zigbook is plagiarizing the zigtools playground
# > Generated images: ['10_Years_Of_Writing_A_Blog_Nobody_Reads.png', '1964_recompiling_engine_documentation_2001_pdf.png', 'A_New_Ai_Winter_Is_Coming.png', 'a_new_little_prince_museum_has_opened_its_doors_in_switzerland.png', 'a_new_myth_appeared_during_the_presidential_campaign_of_andrew_jackson.png', 'A_Vector_Graphics_Workstation_From_The_70s.png', 'accessowl_yc_s22_is_hiring_a_technical_account_manager_iam.png', 'After_Windows_Update__Password_Icon_Invisible__Click_Where_It_Used_To_Be.png', 'Ai_Agents_Find__4_6m_In_Blockchain_Smart_Contract_Exploits.png', 'all_it_takes_is_for_one_to_work_out.png', 'Amazon_Faces_Faa_Probe_After_Delivery_Drone_Snaps_Internet_Cable_In_Texas.png', 'americans_no_longer_see_four_year_college_degrees_as_worth_the_cost.png', 'an_update_on_the_farphone_s_battery.png', 'anthony_bourdain_s_lost_li_st_s.png', 'Arcee_Trinity_Mini__Us_Trained_Moe_Model.png', 'Around_The_World__Part_27__Planting_Trees.png', 'Ask_Hn__Quality_Of_Recent_Gens_Of_Dell_lenovo_Laptops_Worse_Than_10_Years_Ago.png', 'Ask_Hn__Who_Is_Hiring___december_2025.png', 'Ask_Hn__Who_Wants_To_Be_Hired___december_2025.png', 'be_like_clippy.png', 'Beej_s_Guide_To_Learning_Computer_Science.png', 'Better_Auth__yc_X25__Is_Hiring.png', 'blender_facial_animation_tool_what_else_should_it_do.png', 'bronze_age_mega_settlement_in_kazakhstan_has_advanced_urban_planning__metallurgy.png', 'Cartographers_Have_Been_Hiding_Illustrations_Inside_Switzerland_s_Maps__2020.png', 'Cloud_Init_On_Raspberry_Pi_Os.png', 'Codex__Opus__Gemini_Try_To_Build_Counter_Strike.png', 'datacenters_in_space_aren_t_going_to_work.png', 'Deepseek_V3_2__Pushing_The_Frontier_Of_Open_Large_Language_Models__pdf.png', 'dns_loc_record_2014.png', 'Durin_Is_A_Library_For_Reading_And_Writing_The_Dwarf_Debugging_Format.png', 'Games_Using_Anti_Cheats_And_Their_Compatibility_With_Gnu_linux_Or_Wine_proton.png', 'generating_cats_with_learned_lookup_tables.png', 'Ghostty_Compiled_To_Wasm_With_Xterm_js_Api_Compatibility.png', 'Google__Nvidia__And_Openai.png', 'Google_Unkills_Jpeg_Xl.png', 'hardening_the_c_standard_library_at_scale.png', 'High_Income_Job_Losses_Are_Cooling_Housing_Demand.png', 'Imanim__Modern_Animation_Capabilities_To_Imgui_Applications.png', 'India_Orders_Smartphone_Makers_To_Preload_State_Owned_Cyber_Safety_App.png', 'Instagram_Chief_Orders_Staff_Back_To_The_Office_Five_Days_A_Week_In_2026.png', 'It_s_Been_A_Very_Hard_Year.png', 'John_Giannandrea_To_Retire_From_Apple.png', 'landlock_ing_linux.png', 'Last_Week_On_My_Mac__Losing_Confidence.png', 'leak_confirms_openai_is_preparing_ads_on_chatgpt_for_public_roll_out.png', 'learning_feynman_s_trick_for_integrals.png', 'let_go_of_stackoverflow_communities_must_take_ownership.png', 'matrix_core_programming_on_amd_cdna_architecture.png', 'meshtastic.png', 'mint_is_not_tex.png', 'Mozilla_s_Latest_Quagmire.png', 'post_mortem_of_shai_hulud_attack_on_november_24th__2025.png', 'rare_x_ray_images_of_a_4_5_ton_satellite_that_returned_intact_from_space.png', 'Response_To__ruby_Is_Not_A_Serious_Programming_Language.png', 'Reverse_Math_Shows_Why_Hard_Problems_Are_Hard.png', 'scala.png', 'Self_Hosting_A_Matrix_Server_For_5_Years.png', 'stopping_bad_guys_from_using_my_open_source_project_feedback_wanted.png', 'student_perceptions_of_ai_coding_assistants_in_learning.png', 'Sycophancy_Is_The_First_Llm__dark_Pattern.png', 'Tested__1981_Datsun_280zx_Turbo__1981.png', 'testing_shows_automotive_glassbreakers_can_t_break_modern_automotive_glass.png', 'the_http_query_method.png', 'the_origins_of_scala_2009.png', 'The_Penicillin_Myth.png', 'Tom_Stoppard_Has_Died.png', 'we_re_learning_more_about_what_vitamin_d_does.png', 'What_Will_Enter_The_Public_Domain_In_2026.png', 'Why_I_Stopped_Using_Json_For_My_Apis.png', 'Why_Xor_Eax__Eax.png', 'zero_knowlege_proof_of_compositeness.png', 'zigbook_is_plagiarizing_the_zigtools_playground.png']
#
# ALL FIXED ✅ — Articles and images are present and valid.
# Next: git add/commit/push the changes to your GitHub repo.
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# C:\Users\bc\AppData\Local\Programs\Python\Python313\Lib\site-packages\IPython\core\interactiveshell.py:3707: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
